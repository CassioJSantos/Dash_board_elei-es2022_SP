# %% [markdown]
# # Tratamento da base de dados para criação do Dashboard sobre a votação de São Paulo nas Eleições 2022 em primeiro turno

# %% [markdown]
# O TSE disponibiliza a votação presidencial para cada município/zona/seção em uma base de dados, então precisamos isolar nesta base de dados apenas os dados referentes aos municípios do Estado de São Paulo.
# Para tanto, usaremos a base de dados do TSE para a votação dos demais cargos, identificando todos os municípios do estado e filtrando na base de votos presidenciais nacional.
# ao final teremos duas bases que nos permitirão construir o Dashboard, uma com os votos para o cargo de presidente e outra com os votos para os demais cargos, identificadas para cada município/zona/seção do estado de São Paulo.
#
# Fonte:https://dadosabertos.tse.jus.br/dataset/resultados-2022
#
# link para dowload das bases de dados:
# https://cdn.tse.jus.br/estatistica/sead/odsele/votacao_secao/votacao_secao_2022_BR.zip
# https://cdn.tse.jus.br/estatistica/sead/odsele/votacao_secao/votacao_secao_2022_SP.zip

# %%
import pandas as pd

# %% [markdown]
# Importado a base de dados de votação disponibilizada pelo TSE, por cada zona/seção/município , para o cargo de Presidente da República.
# (Selecionando apenas as colunas que interessam)

# %%
colunas=['NR_TURNO','DT_ELEICAO','NM_MUNICIPIO','NR_ZONA','NR_SECAO','DS_CARGO','NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_LOCAL_VOTACAO']
df_base=pd.read_csv('votacao_secao_2022_BR.csv', encoding='cp1252', sep=';',usecols=colunas)

# %%
df_base.head()
# Out:
#    NR_TURNO  DT_ELEICAO              NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 0         1  02/10/2022                 EUNÁPOLIS      188       319
# 1         1  02/10/2022                CHAPADINHA       42       169
# 2         1  02/10/2022  SANTO ANTÔNIO DA PLATINA       22        93
# 3         1  02/10/2022              CRISTALÂNDIA       13        71
# 4         1  02/10/2022     CAMPOS DOS GOYTACAZES      129       101
#
#      DS_CARGO  NR_VOTAVEL           NM_VOTAVEL  QT_VOTOS  NR_LOCAL_VOTACAO
# 0  PRESIDENTE          15  SIMONE NASSAR TEBET         6              1694
# 1  PRESIDENTE          15  SIMONE NASSAR TEBET         1              1864
# 2  PRESIDENTE          15  SIMONE NASSAR TEBET         8              1074
# 3  PRESIDENTE          15  SIMONE NASSAR TEBET         9              1066
# 4  PRESIDENTE          15  SIMONE NASSAR TEBET        20              1236

# %%
df_base.to_csv('Votação Presidencial por município.csv',index=False)

# %% [markdown]
# Importado a base de dados de votação disponibilizada pelo TSE, por cada zona/seção/município, apenas no estado de São Paulo, para os cargos de Dep.Estadual,Dep.Federal,Senador e Governador.
# (Selecionando apenas as colunas que interessam)

# %%
colunas=['NR_TURNO','DT_ELEICAO','NM_MUNICIPIO','NR_ZONA','NR_SECAO','DS_CARGO','NR_VOTAVEL','NM_VOTAVEL','QT_VOTOS','NR_LOCAL_VOTACAO' ]
df_base_SP=pd.read_csv('votacao_secao_2022_SP.csv', encoding='cp1252', sep=';', usecols=colunas)

# %%
df_base_SP.head()
# Out:
#    NR_TURNO  DT_ELEICAO NM_MUNICIPIO  NR_ZONA  NR_SECAO    DS_CARGO  \
# 0         1  02/10/2022      LIMEIRA       66       225  GOVERNADOR
# 1         1  02/10/2022       SUZANO      181       368  GOVERNADOR
# 2         1  02/10/2022    SÃO PAULO      349        20  GOVERNADOR
# 3         1  02/10/2022    RANCHARIA      106        51  GOVERNADOR
# 4         1  02/10/2022      DIADEMA      222       441  GOVERNADOR
#
#    NR_VOTAVEL                NM_VOTAVEL  QT_VOTOS  NR_LOCAL_VOTACAO
# 0          80  CAROLINA REJAILI VIGLIAR         1              1023
# 1          80  CAROLINA REJAILI VIGLIAR         1              1619
# 2          80  CAROLINA REJAILI VIGLIAR         1              1023
# 3          80  CAROLINA REJAILI VIGLIAR         1              1040
# 4          80  CAROLINA REJAILI VIGLIAR         2              1392

# %%
df_base_SP.to_csv('Votação Estadual_SP por município.csv',index=False)

# %% [markdown]
# # Criando uma lista com todos os municípios de São Paulo

# %%
df_municipios_SP=df_base_SP.NM_MUNICIPIO.unique()

# %%
df_municipios_SP
# Out:
# array(['LIMEIRA', 'SUZANO', 'SÃO PAULO', 'RANCHARIA', 'DIADEMA',
#        'JUNDIAÍ', 'JAÚ', 'PIRASSUNUNGA', 'SANTANA DE PARNAÍBA',
#        'MOGI MIRIM', 'RIO CLARO', 'SÃO JOSÉ DOS CAMPOS', 'OSASCO',
#        'CUNHA', 'SÃO MANUEL', 'SÃO VICENTE', 'CAMPINAS', 'MIRASSOL',
#        'MARÍLIA', 'FRANCA', 'FRANCISCO MORATO', 'ATIBAIA', 'MAUÁ',
#        'PRAIA GRANDE', 'SÃO BERNARDO DO CAMPO', 'DRACENA', 'CAIEIRAS',
#        'MOCOCA', 'SOROCABA', 'SÃO JOÃO DA BOA VISTA', 'BARRA BONITA',
#        'CARAGUATATUBA', 'MOGI DAS CRUZES', 'INDAIATUBA', 'SANTO ANDRÉ',
#        'HORTOLÂNDIA', 'MONTE AZUL PAULISTA', 'VARGEM GRANDE PAULISTA',
#        'BARUERI', 'ITAPECERICA DA SERRA', 'FRANCO DA ROCHA', 'SUMARÉ',
#        'BAURU', 'SALTO', 'CAJAMAR', 'GUARULHOS', 'PRESIDENTE PRUDENTE',
#        'PIRACICABA', 'CAMPO LIMPO PAULISTA', 'MATÃO', 'SÃO ROQUE',
#        'VERA CRUZ', 'IGARAÇU DO TIETÊ', 'ITATIBA', 'SÃO CAETANO DO SUL',
#        'MONTE MOR', 'ARARAQUARA', 'RIBEIRÃO PRETO', 'SÃO CARLOS',
#        'SÃO JOSÉ DO RIO PRETO', 'SANTOS', 'PARAGUAÇU PAULISTA', 'TAUBATÉ',
#        'SÃO SEBASTIÃO', 'FERRAZ DE VASCONCELOS', 'COTIA', 'LEME',
#        'EMBU DAS ARTES', 'TABOÃO DA SERRA', 'AVANHANDAVA', 'ITAPEVI',
#        'MOGI GUAÇU', 'ITAQUAQUECETUBA', 'GUARATINGUETÁ', 'IPAUSSU',
#        'IBATÉ', 'SÃO SIMÃO', 'AMERICANA', 'BOITUVA', 'LORENA', 'CONCHAL',
#        'PEDREGULHO', 'LOUVEIRA', 'PERUÍBE', 'RIBEIRÃO BRANCO', 'JANDIRA',
#        'BARRETOS', 'ILHA SOLTEIRA', 'NOVO HORIZONTE', 'BIRIGUI',
#        'UBATUBA', 'ARUJÁ', 'PIEDADE', 'RIO GRANDE DA SERRA', 'CABREÚVA',
#        'FARTURA', 'OURINHOS', 'SALESÓPOLIS', 'BOTUCATU', 'ASSIS',
#        'TAQUARAL', 'CARAPICUÍBA', 'ITU', 'BASTOS', 'NOVA GRANADA',
#        'ENGENHEIRO COELHO', 'BERTIOGA', 'TAQUARITINGA', 'ITÁPOLIS',
#        'SERRANA', 'LINS', 'IGUAPE', 'TATUÍ', 'MAIRINQUE', 'ITARARÉ',
#        'VIRADOURO', 'PITANGUEIRAS', 'ARARAS', 'GUARUJÁ', 'PORTO FELIZ',
#        'GUARARAPES', 'VOTORANTIM', 'EMBU-GUAÇU', 'AVARÉ', 'ITAPETININGA',
#        'RIBEIRÃO PIRES', 'PINDAMONHANGABA', 'SÃO BENTO DO SAPUCAÍ',
#        'CAÇAPAVA', 'IBITINGA', 'JACAREÍ', 'SANTA CRUZ DO RIO PARDO',
#        'SALTO DE PIRAPORA', 'AMPARO', 'PENÁPOLIS', 'ARAÇARIGUAMA',
#        'PAULÍNIA', 'GUAÍRA', 'URUPÊS', 'COSMÓPOLIS', 'PIRAJUÍ', 'VINHEDO',
#        'ITAPIRA', 'CAPIVARI', 'JAGUARIÚNA', 'CUBATÃO',
#        'SANTA BÁRBARA D OESTE', 'PORTO FERREIRA', 'GUATAPARÁ',
#        'MONTE ALEGRE DO SUL', 'VÁRZEA PAULISTA', 'ILHA COMPRIDA',
#        'ARAÇOIABA DA SERRA', 'IRACEMÁPOLIS', 'POÁ', 'GUARAÇAÍ',
#        'CRUZEIRO', 'RIO DAS PEDRAS', 'BIRITIBA MIRIM', 'BEBEDOURO',
#        'PANORAMA', 'CAMPINA DO MONTE ALEGRE', 'SÃO JOAQUIM DA BARRA',
#        'CÂNDIDO MOTA', 'OSVALDO CRUZ', 'BATATAIS', 'TREMEMBÉ',
#        'JABOTICABAL', 'MIGUELÓPOLIS', 'TAMBAÚ', 'MAIRIPORÃ',
#        'PRESIDENTE EPITÁCIO', 'ITANHAÉM', 'DOIS CÓRREGOS',
#        'PEREIRA BARRETO', 'PIQUETE', 'FLÓRIDA PAULISTA', 'VALINHOS',
#        'TRÊS FRONTEIRAS', 'BARIRI', 'SERTÃOZINHO', 'ARAÇATUBA',
#        'ALUMÍNIO', 'ARTUR NOGUEIRA', 'ITUPEVA', 'BRAGANÇA PAULISTA',
#        'TAQUARITUBA', 'JALES', 'CATANDUVA', 'ITAPEVA',
#        'VARGEM GRANDE DO SUL', 'SÃO PEDRO', 'MACAUBAL', 'PEDREIRA',
#        'TAGUAÍ', 'ORLÂNDIA', 'PILAR DO SUL', 'QUADRA',
#        'ESPÍRITO SANTO DO PINHAL', 'VOTUPORANGA', 'COLINA',
#        'TEODORO SAMPAIO', 'UBARANA', 'TAIAÇU', 'CERQUEIRA CÉSAR',
#        'ANDRADINA', 'PINDORAMA', 'NOVA ALIANÇA', 'NAZARÉ PAULISTA',
#        'SANTA ROSA DE VITERBO', 'ELIAS FAUSTO', 'TABAPUÃ', 'SANTA ISABEL',
#        'PONTAL', 'PEDERNEIRAS', 'ÁGUAS DA PRATA', 'ARAMINA',
#        'PIRAPOZINHO', 'SOCORRO', 'CORDEIRÓPOLIS', 'ÁGUAS DE LINDÓIA',
#        'SÃO SEBASTIÃO DA GRAMA', 'MONTE APRAZÍVEL', 'NOVA ODESSA',
#        'ITARIRI', 'MARTINÓPOLIS', 'CAJOBI', 'DESCALVADO',
#        'SÃO JOSÉ DO RIO PARDO', 'APIAÍ', 'CERQUILHO', 'ITUVERAVA',
#        'PRESIDENTE VENCESLAU', 'SANTA GERTRUDES', 'CAMPOS NOVOS PAULISTA',
#        'TUIUTI', 'FERNANDÓPOLIS', 'GARÇA', 'SERRA NEGRA', 'ITOBI',
#        'SANTO ANTÔNIO DE POSSE', 'AGUDOS', 'BANANAL', 'TANABI',
#        'OUROESTE', 'ITABERÁ', 'VALPARAÍSO', 'SALES OLIVEIRA', 'MACATUBA',
#        'DOBRADA', 'CAMPOS DO JORDÃO', 'QUINTANA', 'CHAVANTES',
#        'AREIÓPOLIS', 'BADY BASSITT', 'GUAPIAÇU', 'PORANGABA', 'IGARAPAVA',
#        'PARAIBUNA', 'IBIÚNA', 'MOTUCA', 'JARDINÓPOLIS', 'REGISTRO',
#        'RUBINÉIA', 'TIETÊ', 'MONTE ALTO', 'LAVRINHAS', 'CASA BRANCA',
#        'RINCÃO', 'PRADÓPOLIS', 'QUATÁ', 'PIRAJU', 'REGENTE FEIJÓ',
#        'BARRINHA', 'GUAREÍ', 'SANTA BRANCA', 'MONGAGUÁ', 'ITAÍ',
#        'SALTO GRANDE', 'LENÇÓIS PAULISTA', 'COLÔMBIA', 'GUARIBA',
#        'CONCHAS', 'LUÍS ANTÔNIO', 'SANTA CRUZ DA CONCEIÇÃO', 'ARANDU',
#        'PIRACAIA', 'ROSANA', 'JUQUIÁ', 'APARECIDA', 'MORUNGABA',
#        'CASTILHO', 'BORBOREMA', 'CACHOEIRA PAULISTA', 'CAJATI',
#        'PARDINHO', 'ELDORADO', 'SANTA RITA DO PASSA QUATRO', 'CAJURU',
#        'TUPÃ', 'PALMEIRA D OESTE', 'CRAVINHOS', 'PRATÂNIA',
#        'LARANJAL PAULISTA', 'JUQUITIBA', 'CEDRAL', 'GUARAREMA',
#        'PRESIDENTE BERNARDES', 'JERIQUARA', 'POTIRENDABA', 'PEDRA BELA',
#        'NOVA CAMPINA', 'ÁLVARES MACHADO', 'MORRO AGUDO', 'TEJUPÁ',
#        'BARRA DO CHAPÉU', 'ÁGUAS DE SANTA BÁRBARA', 'SAGRES',
#        'CAPÃO BONITO', 'GENERAL SALGADO', 'CLEMENTINA', 'MIRANDÓPOLIS',
#        'LUCIANÓPOLIS', 'GETULINA', 'CACONDE', 'ADAMANTINA', 'POMPÉIA',
#        'SANTA ADÉLIA', 'PIRATININGA', 'JOSÉ BONIFÁCIO', 'VITÓRIA BRASIL',
#        'SALTINHO', 'CÁSSIA DOS COQUEIROS', 'POTIM', 'RESTINGA', 'BARBOSA',
#        'IPUÃ', 'RIBEIRÃO BONITO', 'SANTA FÉ DO SUL',
#        'SÃO JOSÉ DO BARREIRO', 'SANTA CRUZ DAS PALMEIRAS',
#        'PATROCÍNIO PAULISTA', 'ALTINÓPOLIS', 'COSMORAMA', 'LUCÉLIA',
#        'JAMBEIRO', 'CHARQUEADA', 'REDENÇÃO DA SERRA', 'LUTÉCIA',
#        'CAFELÂNDIA', 'ESTIVA GERBI', 'IGARATÁ', 'AMÉRICO BRASILIENSE',
#        'CAIABU', 'VALENTIM GENTIL', 'JUNQUEIRÓPOLIS', 'OLÍMPIA',
#        'DUARTINA', 'RIOLÂNDIA', 'ROSEIRA', 'BOM JESUS DOS PERDÕES',
#        'PROMISSÃO', 'SÃO PEDRO DO TURVO', 'ILHABELA', 'PARIQUERA-AÇU',
#        'NANTES', 'BRODOWSKI', 'PIRANGI', 'PACAEMBU', 'SERRA AZUL',
#        'NOVA INDEPENDÊNCIA', 'JARINU', 'MOMBUCA', 'ANGATUBA', 'URÂNIA',
#        'IEPÊ', 'TORRINHA', 'MARACAÍ', 'MONTEIRO LOBATO', 'AGUAÍ',
#        'SÃO MIGUEL ARCANJO', 'TAPIRATIBA', 'PIQUEROBI',
#        'SANTO ANTÔNIO DO ARACANGUÁ', 'ESPÍRITO SANTO DO TURVO', 'DUMONT',
#        'SANTA CRUZ DA ESPERANÇA', 'SANTA LÚCIA', 'POLONI',
#        'BOM SUCESSO DE ITARARÉ', 'PINHALZINHO', 'NOVA EUROPA', 'HOLAMBRA',
#        'RIBEIRÃO GRANDE', 'ITAPORANGA', 'BROTAS', 'BURITIZAL',
#        'PONTES GESTAL', 'BILAC', 'GUAIÇARA', 'BURI', 'BÁLSAMO',
#        'CAPELA DO ALTO', 'MARINÓPOLIS', 'LUPÉRCIO', 'ITIRAPINA',
#        'ITIRAPUÃ', 'SANTO ANASTÁCIO', 'SANTA ERNESTINA', 'ORIENTE',
#        'SEVERÍNIA', 'ANALÂNDIA', 'IBIRAREMA', 'CARDOSO', 'IPERÓ',
#        'AREIAS', 'PALMITAL', 'TACIBA', 'JABORANDI', 'GUAPIARA', 'ITAJOBI',
#        'CANANÉIA', 'ÁLVARO DE CARVALHO', 'RINÓPOLIS', 'MIRACATU',
#        'OURO VERDE', 'IPEÚNA', 'GUARÁ', 'SANTO ANTÔNIO DO PINHAL',
#        'POPULINA', 'PARANAPANEMA', 'CANAS', 'CATIGUÁ',
#        'RIBEIRÃO CORRENTE', 'MARABÁ PAULISTA', 'LAGOINHA',
#        'CRISTAIS PAULISTA', 'MINEIROS DO TIETÊ', 'LAVÍNIA',
#        'BERNARDINO DE CAMPOS', 'SÃO LUÍS DO PARAITINGA', 'BURITAMA',
#        'SABINO', 'GAVIÃO PEIXOTO', 'PAULO DE FARIA', 'BALBINOS',
#        'SANTA RITA D OESTE', 'OCAUÇU', 'SANTA MARIA DA SERRA', 'FERNÃO',
#        'SANTO ANTÔNIO DA ALEGRIA', 'TAQUARIVAÍ', 'IBIRÁ', 'ALTO ALEGRE',
#        'SARAPUÍ', 'AURIFLAMA', 'PALESTINA', 'TUPI PAULISTA',
#        'AMÉRICO DE CAMPOS', 'ITATINGA', 'JOANÓPOLIS', 'DIVINOLÂNDIA',
#        'ADOLFO', 'ICÉM', 'CESÁRIO LANGE', 'MERIDIANO', 'FERNANDO PRESTES',
#        'EUCLIDES DA CUNHA PAULISTA', 'MURUTINGA DO SUL', 'MONÇÕES',
#        'BREJO ALEGRE', 'PEREIRAS', 'NATIVIDADE DA SERRA', 'INDIANA',
#        'SANTO EXPEDITO', 'RAFARD', 'IACRI', 'PIRAPORA DO BOM JESUS',
#        'MENDONÇA', 'SETE BARRAS', 'SÃO LOURENÇO DA SERRA', 'ARIRANHA',
#        'ITAPUÍ', 'IRAPURU', 'SANTA ALBERTINA', 'NOVAIS', 'GLICÉRIO',
#        'PARAÍSO', 'PRESIDENTE ALVES', 'PAULICÉIA', 'LINDÓIA',
#        'SANTO ANTÔNIO DO JARDIM', 'LUIZIÂNIA', 'NIPOÃ', 'PEDRO DE TOLEDO',
#        'NUPORANGA', 'SÃO JOÃO DO PAU D ALHO', 'ECHAPORÃ', 'RIBEIRA',
#        'BOFETE', 'IPORANGA', 'TURIÚBA', 'UCHOA', 'TARUMÃ', 'JACUPIRANGA',
#        'ITAPURA', 'NEVES PAULISTA', 'VARGEM', 'CORUMBATAÍ',
#        'SÃO JOÃO DAS DUAS PONTES', 'SÃO JOSÉ DA BELA VISTA', 'TAPIRAÍ',
#        'TERRA ROXA', 'MANDURI', 'ANHUMAS', 'JUMIRIM', 'HERCULÂNDIA',
#        'PLATINA', 'NOVA CANAÃ PAULISTA', 'BOA ESPERANÇA DO SUL',
#        'OSCAR BRESSANE', 'SUD MENNUCCI', 'MIRANTE DO PARANAPANEMA',
#        'ITAOCA', 'ALTAIR', 'GUARACI', 'TAIÚVA', 'REGINÓPOLIS', 'PARAPUÃ',
#        'GUARANTÃ', 'PALMARES PAULISTA', 'JÚLIO MESQUITA',
#        'VISTA ALEGRE DO ALTO', 'SALMOURÃO', 'ONDA VERDE', 'IARAS',
#        'COROADOS', 'RIBEIRÃO DOS ÍNDIOS', 'GUAIMBÊ', 'IRAPUÃ',
#        'SANTA SALETE', 'QUELUZ', 'ORINDIÚVA', 'ESTRELA D OESTE',
#        'FLORA RICA', 'SANTA MERCEDES', 'SEBASTIANÓPOLIS DO SUL',
#        'ALFREDO MARCONDES', 'SANDOVALINA', 'GASTÃO VIDIGAL', 'ASPÁSIA',
#        'AREALVA', 'PARANAPUÃ', 'TRABIJU', 'BOREBI', 'DOURADO', 'PIACATU',
#        'SUZANÁPOLIS', 'TABATINGA', 'IACANGA', 'BARRA DO TURVO',
#        'RUBIÁCEA', 'AVAÍ', 'TURMALINA', 'GABRIEL MONTEIRO', 'NARANDIBA',
#        'MACEDÔNIA', 'JACI', 'URU', 'MONTE CASTELO', 'TARABAI',
#        'NOVA LUZITÂNIA', 'ALVINLÂNDIA', 'CAIUÁ', 'ARAPEÍ',
#        'CORONEL MACEDO', 'SALES', 'PONGAÍ', 'PEDRANÓPOLIS', 'NHANDEARA',
#        'ANHEMBI', 'BARÃO DE ANTONINA', 'ESTRELA DO NORTE',
#        'ÁLVARES FLORENCE', 'DOLCINÓPOLIS', 'SANTÓPOLIS DO AGUAPEÍ',
#        'PEDRINHAS PAULISTA', 'CRUZÁLIA', 'ÁGUAS DE SÃO PEDRO',
#        'INDIAPORÃ', 'FLOREAL', 'BRAÚNA', 'JOÃO RAMALHO', 'BOCAINA',
#        'IPIGUÁ', 'MARIÁPOLIS', 'CANITAR', 'TIMBURI', 'CABRÁLIA PAULISTA',
#        'NOVA CASTILHO', 'BORACÉIA', 'GUZOLÂNDIA', 'MAGDA', 'LOURDES',
#        'QUEIROZ', 'ZACARIAS', 'SILVEIRAS', 'GUARANI D OESTE', 'PLANALTO',
#        'ALAMBARI', 'RIVERSUL', 'UBIRAJARA', 'MIRASSOLÂNDIA', 'EMBAÚBA',
#        'SÃO FRANCISCO', 'MARAPOAMA', 'ITAPIRAPUÃ PAULISTA',
#        'INÚBIA PAULISTA', 'TORRE DE PEDRA', 'PAULISTÂNIA',
#        'RIBEIRÃO DO SUL', 'ÓLEO', 'PRACINHA', 'CÂNDIDO RODRIGUES',
#        'SANTA CLARA D OESTE', 'GÁLIA', 'PARISI', 'MIRA ESTRELA',
#        'APARECIDA D OESTE', 'UNIÃO PAULISTA', 'RIFAINA', 'PONTALINDA',
#        'SÃO JOÃO DE IRACEMA', 'DIRCE REIS', 'MESÓPOLIS',
#        'NOVA GUATAPORANGA', 'BENTO DE ABREU', 'SARUTAIÁ', 'ELISIÁRIO',
#        'ARCO-ÍRIS', 'EMILIANÓPOLIS', 'SANTANA DA PONTE PENSA', 'FLORÍNEA',
#        'ITAJU', 'BORÁ'], dtype=object)

# %% [markdown]
# # Filtrando a votação presidencial apenas para os municípios de São Paulo

# %%
df_presidencial_SP_municipios=df_base[df_base['NM_MUNICIPIO'].isin(df_municipios_SP)]

# %%
df_presidencial_SP_municipios.tail(15)
# Out:
#          NR_TURNO  DT_ELEICAO                NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 3529734         1  02/10/2022                       IARAS      205        20
# 3529736         1  02/10/2022                      OSASCO      277        29
# 3529743         1  02/10/2022                        LINS       67        84
# 3529759         1  02/10/2022                   SÃO PAULO      254       472
# 3529764         1  02/10/2022                       SALTO      221        60
# 3529770         1  02/10/2022  SANTA RITA DO PASSA QUATRO      116        47
# 3529771         1  02/10/2022                   SÃO PAULO      375       419
# 3529773         1  02/10/2022                   SÃO PAULO      326       396
# 3529777         1  02/10/2022                     ITAPIRA       54       151
# 3529778         1  02/10/2022                      ARARAS       14        36
# 3529779         1  02/10/2022                     ITATIBA       58        21
# 3529796         1  02/10/2022                   SÃO PAULO      251       141
# 3529797         1  02/10/2022                   SÃO PAULO      253       191
# 3529814         1  02/10/2022                 ALTINÓPOLIS      202         6
# 3529819         1  02/10/2022                       BAURU      387        85
#
#            DS_CARGO  NR_VOTAVEL   NM_VOTAVEL  QT_VOTOS  NR_LOCAL_VOTACAO
# 3529734  PRESIDENTE          95  VOTO BRANCO         6              1023
# 3529736  PRESIDENTE          95  VOTO BRANCO         6              1031
# 3529743  PRESIDENTE          95  VOTO BRANCO         5              1120
# 3529759  PRESIDENTE          95  VOTO BRANCO        11              1511
# 3529764  PRESIDENTE          95  VOTO BRANCO        12              1120
# 3529770  PRESIDENTE          95  VOTO BRANCO         5              1066
# 3529771  PRESIDENTE          95  VOTO BRANCO         7              1783
# 3529773  PRESIDENTE          95  VOTO BRANCO         9              1295
# 3529777  PRESIDENTE          95  VOTO BRANCO         5              1201
# 3529778  PRESIDENTE          95  VOTO BRANCO         2              1040
# 3529779  PRESIDENTE          95  VOTO BRANCO         2              1031
# 3529796  PRESIDENTE          95  VOTO BRANCO         3              1082
# 3529797  PRESIDENTE          95  VOTO BRANCO         6              1228
# 3529814  PRESIDENTE          95  VOTO BRANCO         1              1015
# 3529819  PRESIDENTE          95  VOTO BRANCO         9              1112

# %%
df_presidencial_SP_municipios.to_csv('Presidencial_SP_municipios.csv', index=False)

# %% [markdown]
# As bases de dados a serem útilizadas são: 'Presidencial_SP_municipios.csv', 'Votação Estadual_SP por município.csv'.
